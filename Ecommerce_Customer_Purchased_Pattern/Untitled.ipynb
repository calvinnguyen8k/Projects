# %%
import pandas as pd

# %%
df = pd.read_csv('./ecommerce_data.csv', encoding="ISO-8859-1",dtype={'CustomerID': str,'InvoiceID': str})

# %%
df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#       InvoiceDate  UnitPrice  CustomerID         Country
# 0  12/1/2010 8:26       2.55     17850.0  United Kingdom
# 1  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 2  12/1/2010 8:26       2.75     17850.0  United Kingdom
# 3  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 4  12/1/2010 8:26       3.39     17850.0  United Kingdom

# %%
df.InvoiceDate = pd.to_datetime(df.InvoiceDate, format="%m/%d/%Y %H:%M")
#Delete the negative values 
df = df.loc[(df['Quantity'] > 0) | (df['UnitPrice'] >= 0)]
df['yearmonth'] = df['InvoiceDate'].apply(lambda x: (100*x.year) + x.month)
df['Week'] = df['InvoiceDate'].apply(lambda x: x.strftime('%W'))
df['day'] = df['InvoiceDate'].apply(lambda x: x.strftime('%d'))
df['Weekday'] = df['InvoiceDate'].apply(lambda x: x.strftime('%w'))
df['hour'] = df['InvoiceDate'].apply(lambda x: x.strftime('%H'))
df['total_dollars'] = df['Quantity']*df['UnitPrice']
df.to_csv('./ecommerce_data1.csv')

# %%
df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           InvoiceDate  UnitPrice  CustomerID         Country  yearmonth Week  \
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom     201012   48
# 1 2010-12-01 08:26:00       3.39     17850.0  United Kingdom     201012   48
# 2 2010-12-01 08:26:00       2.75     17850.0  United Kingdom     201012   48
# 3 2010-12-01 08:26:00       3.39     17850.0  United Kingdom     201012   48
# 4 2010-12-01 08:26:00       3.39     17850.0  United Kingdom     201012   48
#
#   day Weekday hour  total_dollars
# 0  01       3   08          15.30
# 1  01       3   08          20.34
# 2  01       3   08          22.00
# 3  01       3   08          20.34
# 4  01       3   08          20.34

# %%
set(df['Weekday'])
# Out:
# {'0', '1', '2', '3', '4', '5'}
